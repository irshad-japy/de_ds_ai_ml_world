# %% [markdown]
# ### Categorical variables encoding
# ## Dummy Variables & One-Hot Encoding
# To represent categorical variable value with numerical variable for better use.
# Dummy variables are binary indicators (0 or 1) created to represent categories in a dataset. Each category of a categorical variable is turned into a separate column, where:
#
# 1 means the category is present.
# 0 means the category is absent.
#
# Why Use Dummy Variables?
#
# Compatibility with Machine Learning: Many machine learning models need numerical data, so we convert categories into numbers.

# %%
import pandas as pd

# %%
df = pd.read_csv('ai_job_market_insights.csv')

# %%
df.head()
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills     Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.165243
# 1            Medium            High           Marketing   93792.562466
# 2            Medium            High        UX/UI Design  107170.263069
# 3               Low            High  Project Management   93027.953758
# 4               Low             Low          JavaScript   87752.922171
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# 2             Yes                Growth
# 3              No                Growth
# 4             Yes               Decline

# %%
df.columns
# Out:
# Index(['Job_Title', 'Industry', 'Company_Size', 'Location',
#        'AI_Adoption_Level', 'Automation_Risk', 'Required_Skills', 'Salary_USD',
#        'Remote_Friendly', 'Job_Growth_Projection'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Job_Title                0
# Industry                 0
# Company_Size             0
# Location                 0
# AI_Adoption_Level        0
# Automation_Risk          0
# Required_Skills          0
# Salary_USD               0
# Remote_Friendly          0
# Job_Growth_Projection    0
# dtype: int64

# %%
df['Job_Title'].value_counts()
# Out:
# Job_Title
# Data Scientist           62
# HR Manager               57
# Cybersecurity Analyst    55
# UX Designer              54
# AI Researcher            51
# Sales Manager            49
# Marketing Specialist     48
# Operations Manager       44
# Software Engineer        41
# Product Manager          39
# Name: count, dtype: int64

# %%
df['Job_Title'].unique()
# Out:
# array(['Cybersecurity Analyst', 'Marketing Specialist', 'AI Researcher',
#        'Sales Manager', 'UX Designer', 'HR Manager', 'Product Manager',
#        'Software Engineer', 'Data Scientist', 'Operations Manager'],
#       dtype=object)

# %%
dummy_df = pd.get_dummies(df)
dummy_df
# Out:
#         Salary_USD  Job_Title_AI Researcher  Job_Title_Cybersecurity Analyst  \
# 0    111392.165243                    False                             True
# 1     93792.562466                    False                            False
# 2    107170.263069                     True                            False
# 3     93027.953758                    False                            False
# 4     87752.922171                    False                             True
# ..             ...                      ...                              ...
# 495  105821.394046                    False                            False
# 496  119794.992146                    False                             True
# 497   79644.933099                    False                             True
# 498   77642.150625                    False                            False
# 499   68764.378921                    False                            False
#
#      Job_Title_Data Scientist  Job_Title_HR Manager  \
# 0                       False                 False
# 1                       False                 False
# 2                       False                 False
# 3                       False                 False
# 4                       False                 False
# ..                        ...                   ...
# 495                      True                 False
# 496                     False                 False
# 497                     False                 False
# 498                     False                 False
# 499                     False                  True
#
#      Job_Title_Marketing Specialist  Job_Title_Operations Manager  \
# 0                             False                         False
# 1                              True                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
# ..                              ...                           ...
# 495                           False                         False
# 496                           False                         False
# 497                           False                         False
# 498                           False                          True
# 499                           False                         False
#
#      Job_Title_Product Manager  Job_Title_Sales Manager  \
# 0                        False                    False
# 1                        False                    False
# 2                        False                    False
# 3                        False                     True
# 4                        False                    False
# ..                         ...                      ...
# 495                      False                    False
# 496                      False                    False
# 497                      False                    False
# 498                      False                    False
# 499                      False                    False
#
#      Job_Title_Software Engineer  ...  Required_Skills_Marketing  \
# 0                          False  ...                      False
# 1                          False  ...                       True
# 2                          False  ...                      False
# 3                          False  ...                      False
# 4                          False  ...                      False
# ..                           ...  ...                        ...
# 495                        False  ...                      False
# 496                        False  ...                      False
# 497                        False  ...                      False
# 498                        False  ...                      False
# 499                        False  ...                      False
#
#      Required_Skills_Project Management  Required_Skills_Python  \
# 0                                 False                   False
# 1                                 False                   False
# 2                                 False                   False
# 3                                  True                   False
# 4                                 False                   False
# ..                                  ...                     ...
# 495                               False                   False
# 496                               False                   False
# 497                               False                   False
# 498                               False                    True
# 499                                True                   False
#
#      Required_Skills_Sales  Required_Skills_UX/UI Design  Remote_Friendly_No  \
# 0                    False                          True               False
# 1                    False                         False                True
# 2                    False                          True               False
# 3                    False                         False                True
# 4                    False                         False               False
# ..                     ...                           ...                 ...
# 495                  False                         False               False
# 496                  False                          True                True
# 497                  False                          True               False
# 498                  False                         False               False
# 499                  False                         False               False
#
#      Remote_Friendly_Yes  Job_Growth_Projection_Decline  \
# 0                   True                          False
# 1                  False                           True
# 2                   True                          False
# 3                  False                          False
# 4                   True                           True
# ..                   ...                            ...
# 495                 True                          False
# 496                False                           True
# 497                 True                          False
# 498                 True                          False
# 499                 True                           True
#
#      Job_Growth_Projection_Growth  Job_Growth_Projection_Stable
# 0                            True                         False
# 1                           False                         False
# 2                            True                         False
# 3                            True                         False
# 4                           False                         False
# ..                            ...                           ...
# 495                         False                          True
# 496                         False                         False
# 497                         False                          True
# 498                         False                          True
# 499                         False                         False
#
# [500 rows x 55 columns]

# %%
dummy_df.isnull().sum()
# Out:
# Salary_USD                            0
# Job_Title_AI Researcher               0
# Job_Title_Cybersecurity Analyst       0
# Job_Title_Data Scientist              0
# Job_Title_HR Manager                  0
# Job_Title_Marketing Specialist        0
# Job_Title_Operations Manager          0
# Job_Title_Product Manager             0
# Job_Title_Sales Manager               0
# Job_Title_Software Engineer           0
# Job_Title_UX Designer                 0
# Industry_Education                    0
# Industry_Energy                       0
# Industry_Entertainment                0
# Industry_Finance                      0
# Industry_Healthcare                   0
# Industry_Manufacturing                0
# Industry_Retail                       0
# Industry_Technology                   0
# Industry_Telecommunications           0
# Industry_Transportation               0
# Company_Size_Large                    0
# Company_Size_Medium                   0
# Company_Size_Small                    0
# Location_Berlin                       0
# Location_Dubai                        0
# Location_London                       0
# Location_New York                     0
# Location_Paris                        0
# Location_San Francisco                0
# Location_Singapore                    0
# Location_Sydney                       0
# Location_Tokyo                        0
# Location_Toronto                      0
# AI_Adoption_Level_High                0
# AI_Adoption_Level_Low                 0
# AI_Adoption_Level_Medium              0
# Automation_Risk_High                  0
# Automation_Risk_Low                   0
# Automation_Risk_Medium                0
# Required_Skills_Communication         0
# Required_Skills_Cybersecurity         0
# Required_Skills_Data Analysis         0
# Required_Skills_JavaScript            0
# Required_Skills_Machine Learning      0
# Required_Skills_Marketing             0
# Required_Skills_Project Management    0
# Required_Skills_Python                0
# Required_Skills_Sales                 0
# Required_Skills_UX/UI Design          0
# Remote_Friendly_No                    0
# Remote_Friendly_Yes                   0
# Job_Growth_Projection_Decline         0
# Job_Growth_Projection_Growth          0
# Job_Growth_Projection_Stable          0
# dtype: int64

# %% [markdown]
# it will remove useless columns

# %%
dummy_df = pd.get_dummies(df, drop_first = True)
dummy_df
# Out:
#         Salary_USD  Job_Title_Cybersecurity Analyst  Job_Title_Data Scientist  \
# 0    111392.165243                             True                     False
# 1     93792.562466                            False                     False
# 2    107170.263069                            False                     False
# 3     93027.953758                            False                     False
# 4     87752.922171                             True                     False
# ..             ...                              ...                       ...
# 495  105821.394046                            False                      True
# 496  119794.992146                             True                     False
# 497   79644.933099                             True                     False
# 498   77642.150625                            False                     False
# 499   68764.378921                            False                     False
#
#      Job_Title_HR Manager  Job_Title_Marketing Specialist  \
# 0                   False                           False
# 1                   False                            True
# 2                   False                           False
# 3                   False                           False
# 4                   False                           False
# ..                    ...                             ...
# 495                 False                           False
# 496                 False                           False
# 497                 False                           False
# 498                 False                           False
# 499                  True                           False
#
#      Job_Title_Operations Manager  Job_Title_Product Manager  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
# ..                            ...                        ...
# 495                         False                      False
# 496                         False                      False
# 497                         False                      False
# 498                          True                      False
# 499                         False                      False
#
#      Job_Title_Sales Manager  Job_Title_Software Engineer  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                       True                        False
# 4                      False                        False
# ..                       ...                          ...
# 495                    False                        False
# 496                    False                        False
# 497                    False                        False
# 498                    False                        False
# 499                    False                        False
#
#      Job_Title_UX Designer  ...  Required_Skills_JavaScript  \
# 0                    False  ...                       False
# 1                    False  ...                       False
# 2                    False  ...                       False
# 3                    False  ...                       False
# 4                    False  ...                        True
# ..                     ...  ...                         ...
# 495                  False  ...                       False
# 496                  False  ...                       False
# 497                  False  ...                       False
# 498                  False  ...                       False
# 499                  False  ...                       False
#
#      Required_Skills_Machine Learning  Required_Skills_Marketing  \
# 0                               False                      False
# 1                               False                       True
# 2                               False                      False
# 3                               False                      False
# 4                               False                      False
# ..                                ...                        ...
# 495                              True                      False
# 496                             False                      False
# 497                             False                      False
# 498                             False                      False
# 499                             False                      False
#
#      Required_Skills_Project Management  Required_Skills_Python  \
# 0                                 False                   False
# 1                                 False                   False
# 2                                 False                   False
# 3                                  True                   False
# 4                                 False                   False
# ..                                  ...                     ...
# 495                               False                   False
# 496                               False                   False
# 497                               False                   False
# 498                               False                    True
# 499                                True                   False
#
#      Required_Skills_Sales  Required_Skills_UX/UI Design  Remote_Friendly_Yes  \
# 0                    False                          True                 True
# 1                    False                         False                False
# 2                    False                          True                 True
# 3                    False                         False                False
# 4                    False                         False                 True
# ..                     ...                           ...                  ...
# 495                  False                         False                 True
# 496                  False                          True                False
# 497                  False                          True                 True
# 498                  False                         False                 True
# 499                  False                         False                 True
#
#      Job_Growth_Projection_Growth  Job_Growth_Projection_Stable
# 0                            True                         False
# 1                           False                         False
# 2                            True                         False
# 3                            True                         False
# 4                           False                         False
# ..                            ...                           ...
# 495                         False                          True
# 496                         False                         False
# 497                         False                          True
# 498                         False                          True
# 499                         False                         False
#
# [500 rows x 46 columns]

# %%
    import pandas as pd

# Create a DataFrame
df = pd.DataFrame({
    'Color': ['Red', 'Blue', 'Green', 'Red', 'Blue'],
    'Size': ['S', 'M', 'L', 'L', 'M']
})

# Apply get_dummies to create dummy variables
dummies = pd.get_dummies(df)
dummies
# Out:
#    Color_Blue  Color_Green  Color_Red  Size_L  Size_M  Size_S
# 0       False        False       True   False   False    True
# 1        True        False      False   False    True   False
# 2       False         True      False    True   False   False
# 3       False        False       True    True   False   False
# 4        True        False      False   False    True   False

# %%
# Apply get_dummies on only the 'Color' column
dummies = pd.get_dummies(df, columns=['Color'])
dummies
# Out:
#   Size  Color_Blue  Color_Green  Color_Red
# 0    S       False        False       True
# 1    M        True        False      False
# 2    L       False         True      False
# 3    L       False        False       True
# 4    M        True        False      False

# %%
# Apply get_dummies with drop_first=True
dummies = pd.get_dummies(df, drop_first=True)
dummies
# Out:
#    Color_Green  Color_Red  Size_M  Size_S
# 0        False       True   False    True
# 1        False      False    True   False
# 2         True      False   False   False
# 3        False       True   False   False
# 4        False      False    True   False

# %%
# Apply get_dummies with dtype=np.int8
dummies = pd.get_dummies(df, dtype='int8')
dummies.dtypes
# Out:
# Color_Blue     int8
# Color_Green    int8
# Color_Red      int8
# Size_L         int8
# Size_M         int8
# Size_S         int8
# dtype: object

# %%
There are two types of categorical variables?
1. Oridinal variables: categories can be meaningfully ordered

# %%
# Import necessary libraries
import pandas as pd

# Sample dataset
data = {
    'Country': ['USA', 'France', 'Germany', 'USA', 'Germany', 'France'],
    'Purchased': ['Yes', 'No', 'No', 'Yes', 'Yes', 'No']
}

# Create a DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Country Purchased
# 0      USA       Yes
# 1   France        No
# 2  Germany        No
# 3      USA       Yes
# 4  Germany       Yes
# 5   France        No

# %%
# Use get_dummies() to one-hot encode the 'Country' column
df_encoded = pd.get_dummies(df, columns=['Country'])

# Show the resulting DataFrame
print(df_encoded)
# Out:
#   Purchased  Country_France  Country_Germany  Country_USA
# 0       Yes           False            False         True
# 1        No            True            False        False
# 2        No           False             True        False
# 3       Yes           False            False         True
# 4       Yes           False             True        False
# 5        No            True            False        False

# %%
df_encoded = pd.get_dummies(df, columns=['Country'], drop_first=True)
df_encoded
# Out:
#   Purchased  Country_Germany  Country_USA
# 0       Yes            False         True
# 1        No            False        False
# 2        No             True        False
# 3       Yes            False         True
# 4       Yes             True        False
# 5        No            False        False

# %%
import pandas as pd

# Sample dataset
data = {
    'Country': ['USA', None, 'Germany', 'France', 'Germany', 'USA'],
    'Purchased': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
    'Age': [25, 30, 35, 40, 45, 50]
}

# Creating a DataFrame
df = pd.DataFrame(data)
df
# Out:
#    Country Purchased  Age
# 0      USA       Yes   25
# 1     None        No   30
# 2  Germany       Yes   35
# 3   France        No   40
# 4  Germany       Yes   45
# 5      USA        No   50

# %%
# Using get_dummies with a prefix and custom separator
df_dummies_prefix = pd.get_dummies(df, columns=['Country'], prefix='Region', prefix_sep='-', drop_first=True)
df_dummies_prefix
# Out:
#   Purchased  Age  Region-Germany  Region-USA
# 0       Yes   25           False        True
# 1        No   30           False       False
# 2       Yes   35            True       False
# 3        No   40           False       False
# 4       Yes   45            True       False
# 5        No   50           False        True

# %%
df
# Out:
#    Country Purchased  Age
# 0      USA       Yes   25
# 1     None        No   30
# 2  Germany       Yes   35
# 3   France        No   40
# 4  Germany       Yes   45
# 5      USA        No   50

# %%
df_dummies_nan = pd.get_dummies(df, columns=['Country'], dummy_na=True)
df_dummies_nan
# Out:
#   Purchased  Age  Country_France  Country_Germany  Country_USA  Country_nan
# 0       Yes   25           False            False         True        False
# 1        No   30           False            False        False         True
# 2       Yes   35           False             True        False        False
# 3        No   40            True            False        False        False
# 4       Yes   45           False             True        False        False
# 5        No   50           False            False         True        False
